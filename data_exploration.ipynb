# %% [markdown]
# # Imports

# %%
import calendar
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# # Create dataframe of all year sales

# %%
months = list(calendar.month_name)
dataframes = list()

for num in range(1, 13, 1):
    dataframes.append(pd.read_csv('Data/Sales_' + months[num] + '_2019.csv'))

sales_df = pd.concat(dataframes)
sales_df.to_csv('Data/Sales_2019.csv', index=False)
sales_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       141234                      iPhone                1        700
# 1       141235    Lightning Charging Cable                1      14.95
# 2       141236            Wired Headphones                2      11.99
# 3       141237            27in FHD Monitor                1     149.99
# 4       141238            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# # Generate Graphs

# %%
def bar_plot(data: list, title: str, filename: str):
    
    species = ['Simple MapReduce', 'Combiner Based', 'In Mapper']
    penguin_means = {
        '1 Core': data[0],
        '10 Core': data[1]
    }

    x = np.arange(len(species))
    width = 0.25
    multiplier = 0

    fig, ax = plt.subplots(layout='constrained')

    for attribute, measurement in penguin_means.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, measurement, width, label=attribute)
        ax.bar_label(rects, padding=3)
        multiplier += 1

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Time Taken', fontsize = 15)
    ax.set_title(title, fontsize = 15)
    ax.set_xlabel('Design Patterns', fontsize = 15)
    ax.set_xticks(x + width, species)
    ax.legend(loc='upper right', ncols=3)
    plt.savefig(f'Images/{filename}')
    plt.show()

# %% [markdown]
# ## Item Count

# %%
title = 'Design Pattern Vs. Time Taken for Item Count'
data = [[4.3122, 4.1493, 0.8144], [1.68887, 1.52059, 0.875332]]
filename = 'item_count.png'
bar_plot(data, title, filename)

# %% [markdown]
# ## Annual Revenue

# %%
title = 'Design Pattern Vs. Time Taken for Annual Revenue'
data = [[4.3121, 4.1493, 0.8144], [1.87011, 1.71338, 1.06403]]
filename = 'annual_revenue.png'
bar_plot(data, title, filename)

# %% [markdown]
# ## Item-wise monthly revenue

# %%
title = 'Design Pattern Vs. Time Taken for Item wise monthly revenue'
data = [[10.3315, 10.0033, 5.6468], [3.98017, 4.01579, 6.48834]]
filename = 'item_wise_monthly_revenue.png'
bar_plot(data, title, filename)

# %% [markdown]
# ## Monthly Revenue

# %%
title = 'Design Pattern Vs. Time Taken for Monthly Revenue'
data = [[9.2423, 8.8924, 5.3215], [4.11613, 4.12685, 6.23392]]
filename = 'monthly_revenue.png'
bar_plot(data, title, filename)

# %% [markdown]
# ## Top K Items

# %%
title = 'Design Pattern Vs. Time Taken for Top K Items'
data = [[10.4907, 9.8415, 5.5945], [3.84811, 3.69894, 6.31022]]
filename = 'top_k_items.png'
bar_plot(data, title, filename)
